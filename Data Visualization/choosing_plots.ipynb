# %% [markdown]
# # How to choose Plots
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Custom seaborn styles
#
# Seaborn has 5 different themes for graphs:
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks
#
# You can choose any of these styles with the function `sns.set_style()` and give the parameter the theme from above
